# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraBCoutinho/Pesquisa_6/blob/main/Results_pesquisa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Resumo Database

# %% [markdown]
# ### liar 6

# %%
#quantidade de fake e nao fake separadamente de train, test e val para o caso de liar 6 e de liar 2 
# %%time 
import pandas as pd
# !pip install ftfy
import ftfy 

""" Regular expression for cleaning the statements"""
import re

hashtag_re = re.compile(r"#\w+")
mention_re = re.compile(r"@\w+")
url_re = re.compile(r"(?:https?://)?(?:[-\w]+\.)+[a-zA-Z]{2,9}[-\w/#~:;.?+=&%@~]*")
extras_re = re.compile("[.;:!\'?,\"()\[\]]")

#dataset
# !pip install datasets
from datasets import load_dataset
dataset = load_dataset('liar')

#data
train=pd.DataFrame(dataset['train'])
test=pd.DataFrame(dataset['test'])
val=pd.DataFrame(dataset['validation'])

def preprocess(text):
    p_text = hashtag_re.sub("[hashtag]",text)
    p_text = mention_re.sub("[mention]",p_text)
    p_text = extras_re.sub("",p_text)
    p_text = url_re.sub("[url]",p_text) #removing url
    p_text = ftfy.fix_text(p_text)
    return p_text.lower()

train['statement']=train['statement'].map(preprocess)
val['statement']=val['statement'].map(preprocess)
test['statement']=test['statement'].map(preprocess)

# specifying features and labels
X_train= train['statement']
X_val=val['statement']
X_test=test['statement']
y_train=train['label']
y_val=val['label']
y_test=test['label']
# Out:
# ...
#      |████████████████████████████████| 64 kB 1.5 MB/s
# ...
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41933 sha256=5183b3479d21b725713bc7552426ac03418bb11caf8db4afea052116f1d5e11f
#   Stored in directory: /root/.cache/pip/wheels/19/f5/38/273eb3b5e76dfd850619312f693716ac4518b498f5ffb6f56d
# Successfully built ftfy
# ...
#      |████████████████████████████████| 312 kB 22.4 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 58.5 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 133 kB 45.8 MB/s
# ...
#      |████████████████████████████████| 243 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 144 kB 69.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 50.5 MB/s
# ...
# Downloading:   0%|          | 0.00/2.33k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# Using custom data configuration default
# ...

# %%
# specifying features and labels
X_train_6= train['statement']
X_val_6=val['statement']
X_test_6=test['statement']
y_train_6=train['label']
y_val_6=val['label']
y_test_6=test['label']

# %%
y_train_6.info
# Out:
# <bound method DataFrame.info of        label
# 0          0
# 1          1
# 2          2
# 3          0
# 4          1
# ...      ...
# 10264      2
# 10265      2
# 10266      1
# 10267      0
# 10268      5
#
# [10269 rows x 1 columns]>

# %%
#Y train 6 
y_train_6=pd.DataFrame(y_train_6)

print(y_train_6[y_train_6['label'] == 0].count())
print(y_train_6[y_train_6['label'] == 0].count()/y_train_6.count())

print(y_train_6[y_train_6['label'] == 1].count())
print(y_train_6[y_train_6['label'] == 1].count()/y_train_6.count())

print(y_train_6[y_train_6['label'] == 2].count())
print(y_train_6[y_train_6['label'] == 2].count()/y_train_6.count())

print(y_train_6[y_train_6['label'] == 3].count())
print(y_train_6[y_train_6['label'] == 3].count()/y_train_6.count())

print(y_train_6[y_train_6['label'] == 4].count())
print(y_train_6[y_train_6['label'] == 4].count()/y_train_6.count())

print(y_train_6[y_train_6['label'] == 5].count())
print(y_train_6[y_train_6['label'] == 5].count()/y_train_6.count())

print(y_train_6[y_train_6['label'] == 6].count())
print(y_train_6[y_train_6['label'] == 6].count()/y_train_6.count())

print(y_train_6[y_train_6['label'] == 0].count()/y_train_6.count()+
      y_train_6[y_train_6['label'] == 1].count()/y_train_6.count()+
      y_train_6[y_train_6['label'] == 2].count()/y_train_6.count()+
      y_train_6[y_train_6['label'] == 3].count()/y_train_6.count()+
      y_train_6[y_train_6['label'] == 4].count()/y_train_6.count()+
      y_train_6[y_train_6['label'] == 5].count()/y_train_6.count()+
      y_train_6[y_train_6['label'] == 6].count()/y_train_6.count())
# Out:
# label    1998
# dtype: int64
# label    0.194566
# dtype: float64
# label    2123
# dtype: int64
# label    0.206739
# dtype: float64
# label    1966
# dtype: int64
# label    0.19145
# dtype: float64
# label    1683
# dtype: int64
# label    0.163891
# dtype: float64
# label    1657
# dtype: int64
# label    0.161359
# dtype: float64
# label    842
# dtype: int64
# label    0.081994
# dtype: float64
# label    0
# dtype: int64
# label    0.0
# dtype: float64
# label    1.0
# dtype: float64

# %%
#Y test 6 
y_test_6=pd.DataFrame(y_test_6)

print(y_test_6[y_test_6['label'] == 0].count())
print(y_test_6[y_test_6['label'] == 0].count()/y_test_6.count())

print(y_test_6[y_test_6['label'] == 1].count())
print(y_test_6[y_test_6['label'] == 1].count()/y_test_6.count())


print(y_test_6[y_test_6['label'] == 2].count())
print(y_test_6[y_test_6['label'] == 2].count()/y_test_6.count())


print(y_test_6[y_test_6['label'] == 3].count())
print(y_test_6[y_test_6['label'] == 3].count()/y_test_6.count())


print(y_test_6[y_test_6['label'] == 4].count())
print(y_test_6[y_test_6['label'] == 4].count()/y_test_6.count())


print(y_test_6[y_test_6['label'] == 5].count())
print(y_test_6[y_test_6['label'] == 5].count()/y_test_6.count())


print(y_test_6[y_test_6['label'] == 6].count())
print(y_test_6[y_test_6['label'] == 6].count()/y_test_6.count())
# Out:
# label    250
# dtype: int64
# label    0.194856
# dtype: float64
# label    267
# dtype: int64
# label    0.208106
# dtype: float64
# label    249
# dtype: int64
# label    0.194076
# dtype: float64
# label    211
# dtype: int64
# label    0.164458
# dtype: float64
# label    214
# dtype: int64
# label    0.166797
# dtype: float64
# label    92
# dtype: int64
# label    0.071707
# dtype: float64
# label    0
# dtype: int64
# label    0.0
# dtype: float64

# %%
#Y val 6 
y_val_6=pd.DataFrame(y_val_6)

print(y_val_6[y_val_6['label'] == 0].count())
print(y_val_6[y_val_6['label'] == 0].count()/y_val_6.count())

print(y_val_6[y_val_6['label'] == 1].count())
print(y_val_6[y_val_6['label'] == 1].count()/y_val_6.count())

print(y_val_6[y_val_6['label'] == 2].count())
print(y_val_6[y_val_6['label'] == 2].count()/y_val_6.count())

print(y_val_6[y_val_6['label'] == 3].count())
print(y_val_6[y_val_6['label'] == 3].count()/y_val_6.count())

print(y_val_6[y_val_6['label'] == 4].count())
print(y_val_6[y_val_6['label'] == 4].count()/y_val_6.count())

print(y_val_6[y_val_6['label'] == 5].count())
print(y_val_6[y_val_6['label'] == 5].count()/y_val_6.count())

print(y_val_6[y_val_6['label'] == 6].count())
print(y_val_6[y_val_6['label'] == 6].count()/y_val_6.count())
# Out:
# label    263
# dtype: int64
# label    0.204829
# dtype: float64
# label    248
# dtype: int64
# label    0.193146
# dtype: float64
# label    251
# dtype: int64
# label    0.195483
# dtype: float64
# label    169
# dtype: int64
# label    0.13162
# dtype: float64
# label    237
# dtype: int64
# label    0.184579
# dtype: float64
# label    116
# dtype: int64
# label    0.090343
# dtype: float64
# label    0
# dtype: int64
# label    0.0
# dtype: float64

# %%
#Y total 2
y_total_6=pd.concat([y_val_6,y_train_6,y_test_6])

# %%
print(y_total_6[y_total_6['label'] == 0].count())
print(y_total_6[y_total_6['label'] == 0].count()/y_total_6.count())
print(y_total_6[y_total_6['label'] == 1].count())
print(y_total_6[y_total_6['label'] == 1].count()/y_total_6.count())
print(y_total_6[y_total_6['label'] == 2].count())
print(y_total_6[y_total_6['label'] == 2].count()/y_total_6.count())
print(y_total_6[y_total_6['label'] == 3].count())
print(y_total_6[y_total_6['label'] == 3].count()/y_total_6.count())
print(y_total_6[y_total_6['label'] == 4].count())
print(y_total_6[y_total_6['label'] == 4].count()/y_total_6.count())
print(y_total_6[y_total_6['label'] == 5].count())
print(y_total_6[y_total_6['label'] == 5].count()/y_total_6.count())
# Out:
# label    2511
# dtype: int64
# label    0.195622
# dtype: float64
# label    2638
# dtype: int64
# label    0.205516
# dtype: float64
# label    2466
# dtype: int64
# label    0.192116
# dtype: float64
# label    2063
# dtype: int64
# label    0.16072
# dtype: float64
# label    2108
# dtype: int64
# label    0.164226
# dtype: float64
# label    1050
# dtype: int64
# label    0.081801
# dtype: float64

# %%
print(y_train_6.size,y_test_6.size,y_val_6.size)
# Out:
# 10269 1283 1284

# %% [markdown]
# ### Liar 2

# %%
print(y_train_2.size,y_test_2.size,y_val_2.size)
# Out:
# 10269 1283 1284

# %%
print(10269+1283+1284)
# Out:
# 12836

# %%
Original_labels={5:1, 4:1, 3:1, 1:0,2:0,0:0}
train['label'] = train['label'].map(Original_labels)
test['label'] = test['label'].map(Original_labels)
val['label'] = val['label'].map(Original_labels)

# specifying features and labels
X_train_2= pd.DataFrame(train['statement'])
X_val_2=pd.DataFrame(val['statement'])
X_test_2=pd.DataFrame(test['statement'])
y_train_2=pd.DataFrame(train['label'])
y_val_2=pd.DataFrame(val['label'])
y_test_2=pd.DataFrame(test['label'])

# %%
#Y train 2
y_train_2=pd.DataFrame(y_train_2)

print(y_train_2[y_train_2['label'] == 0].count())
print(y_train_2[y_train_2['label'] == 0].count()/y_train_2.count())
print(y_train_2[y_train_2['label'] == 1].count())
print(y_train_2[y_train_2['label'] == 1].count()/y_train_2.count())
# Out:
# label    6087
# dtype: int64
# label    0.592755
# dtype: float64
# label    4182
# dtype: int64
# label    0.407245
# dtype: float64

# %%
#Y test 2
y_test_2=pd.DataFrame(y_test_2)

print(y_test_2[y_test_2['label'] == 0].count())
print(y_test_2[y_test_2['label'] == 0].count()/y_test_2.count())
print(y_test_2[y_test_2['label'] == 1].count())
print(y_test_2[y_test_2['label'] == 1].count()/y_test_2.count())
# Out:
# label    766
# dtype: int64
# label    0.597038
# dtype: float64
# label    517
# dtype: int64
# label    0.402962
# dtype: float64

# %%
#Y val 2
y_val_2=pd.DataFrame(y_val_2)

print(y_val_2[y_val_2['label'] == 0].count())
print(y_val_2[y_val_2['label'] == 0].count()/y_val_2.count())
print(y_val_2[y_val_2['label'] == 1].count())
print(y_val_2[y_val_2['label'] == 1].count()/y_val_2.count())
# Out:
# label    762
# dtype: int64
# label    0.593458
# dtype: float64
# label    522
# dtype: int64
# label    0.406542
# dtype: float64

# %%
#Y total 2
y_total_2=pd.concat([y_val_2,y_train_2,y_test_2])

# %%
print(y_total_2[y_total_2['label'] == 0].count())
print(y_total_2[y_total_2['label'] == 0].count()/y_total_2.count())
print(y_total_2[y_total_2['label'] == 1].count())
print(y_total_2[y_total_2['label'] == 1].count()/y_total_2.count())
# Out:
# label    7615
# dtype: int64
# label    0.593253
# dtype: float64
# label    5221
# dtype: int64
# label    0.406747
# dtype: float64

# %% [markdown]
# ## Resumo Resultados LIAR 2 e 6 (Sem bert)

# %%
from numpy import load
#--Data
# %matplotlib inline
import pandas as pd
import csv
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# !mkdir Data
# !mkdir Data/liar2
# !mkdir Data/liar6

# %%
# function for results of cross-validation
def print_cv_scores_summary(name, scores):
    print("{}: mean = {:.2f}%, sd = {:.2f}%, min = {:.2f}, max = {:.2f}".format(name, scores.mean()*100, scores.std()*100, scores.min()*100, scores.max()*100))


# fucntion for results of model fitting
def print_scores():
    print("Accuracy: ", accuracy_score(y_test, predictions))
    print(classification_report(y_test, predictions))
    print(confusion_matrix(y_test, predictions))
    
# function for displaying confusion matrix
def confusion_matrix_heatmap(cm, index):
    cmdf = pd.DataFrame(cm, index = index, columns=index)
    dims = (10, 8)
    fig, ax = plt.subplots(figsize=dims)
    sns.heatmap(cmdf, annot=True, cmap="BuPu", center=0, fmt='g')
    ax.set_ylabel('Actual')    
    ax.set_xlabel('Predicted')

# function for displaying confusion matrix in percentage terms
def confusion_matrix_percent_heatmap(cm, index):
    cmdf = pd.DataFrame(cm, index = index, columns=index)
    percents = cmdf.div(cmdf.sum(axis=1), axis=0)*100
    dims = (10, 10)
    fig, ax = plt.subplots(figsize=dims)
    sns.heatmap(percents, annot=True, cmap="PiYG", center=0, vmin=0, vmax=100)
    ax.set_ylabel('Actual')    
    ax.set_xlabel('Predicted')
    cbar = ax.collections[0].colorbar
    cbar.set_ticks([0, 25, 50, 75, 100])
    cbar.set_ticklabels(['0%', '25%', '50%', '75%', '100%'])

# %%
table=pd.read_csv('/content/Data/liar2/pred_test.csv')
label_list=np.array(table['label'])
for column in table.columns:
  pred_list=np.array(table[column])
  print(accuracy_score(label_list,pred_list),column)
# Out:
# 0.0 Unnamed: 0
# 1.0 label
# 0.524551831644583 SVM-CV
# 0.5666406858924395 SVM-TFIDF
# 0.603273577552611 SVM-W2V
# 0.5985970381917382 SVM-GLOVE
# 0.5970381917381138 SVM-FAST
# 0.568978955572876 LR-CV
# 0.5806703039750585 LR-TFIDF
# 0.5978176149649259 LR-GLOVE
# 0.5892439594699922 LR-W2V
# 0.6017147310989868 LR-FAST
# 0.5908028059236166 RF-CV
# 0.5720966484801248 RF-TFIDF
# 0.5954793452844894 RF-GLOVE
# 0.603273577552611 RF-W2V
# 0.5869056897895557 RF-FAST
# 0.5580670303975058 NB-CV
# 0.5580670303975058 NB-TFIDF
# 0.5962587685113017 NB-GLOVE
# 0.5681995323460639 NB-W2V
# 0.568978955572876 NB-FAST
# 0.5557287607170693 MLP-CV
# 0.5315666406858924 MLP-TFIDF
# 0.5759937646141855 MLP-GLOVE
# 0.5643024162120032 MLP-W2V
# 0.5946999220576773 MLP-FAST
# 0.573655494933749 EXTRA-CV
# 0.5806703039750585 EXTRA-TFIDF
# 0.5697583787996883 EXTRA-GLOVE
# 0.5939204988308652 EXTRA-W2V
# 0.5845674201091192 EXTRA-FAST
# 0.5526110678098207 KNN-CV
# 0.5526110678098207 KNN-TFIDF
# ...

# %%
table=pd.read_csv('/content/Data/liar2/pred_val.csv')
label_list=np.array(table['label'])
for column in table.columns:
  pred_list=np.array(table[column])
  print(accuracy_score(label_list,pred_list),column)
# Out:
# 0.000778816199376947 Unnamed: 0
# 1.0 label
# 0.5560747663551402 SVM-CV
# 0.5661993769470405 SVM-TFIDF
# 0.5919003115264797 SVM-W2V
# 0.5942367601246106 SVM-GLOVE
# 0.5934579439252337 SVM-FAST
# 0.5568535825545171 LR-CV
# 0.5755451713395638 LR-TFIDF
# 0.5887850467289719 LR-GLOVE
# 0.5693146417445483 LR-W2V
# 0.5919003115264797 LR-FAST
# 0.573208722741433 RF-CV
# 0.5786604361370716 RF-TFIDF
# 0.573208722741433 RF-GLOVE
# 0.5654205607476636 RF-W2V
# 0.5848909657320872 RF-FAST
# 0.5552959501557633 NB-CV
# 0.5669781931464174 NB-TFIDF
# 0.5864485981308412 NB-GLOVE
# 0.5412772585669782 NB-W2V
# 0.5475077881619937 NB-FAST
# 0.5194704049844237 MLP-CV
# 0.5373831775700935 MLP-TFIDF
# 0.5841121495327103 MLP-GLOVE
# 0.5669781931464174 MLP-W2V
# 0.572429906542056 MLP-FAST
# 0.5623052959501558 EXTRA-CV
# 0.5763239875389408 EXTRA-TFIDF
# 0.5786604361370716 EXTRA-GLOVE
# 0.5957943925233645 EXTRA-W2V
# 0.5957943925233645 EXTRA-FAST
# 0.5833333333333334 KNN-CV
# 0.557632398753894 KNN-TFIDF
# ...

# %%
table=pd.read_csv('/content/Data/liar6/pred_test.csv')
label_list=np.array(table['label'])
for column in table.columns:
  pred_list=np.array(table[column])
  print(accuracy_score(label_list,pred_list),column)
# Out:
# 0.0 Unnamed: 0
# 1.0 label
# 0.23304754481683554 SVM-CV
# 0.2572096648480125 SVM-TFIDF
# 0.25019485580670303 SVM-W2V
# 0.24473889321901793 SVM-GLOVE
# 0.24162120031176929 SVM-FAST
# 0.24863600935307872 LR-CV
# 0.24707716289945442 LR-TFIDF
# 0.24240062353858144 LR-GLOVE
# 0.2540919719407638 LR-W2V
# 0.24707716289945442 LR-FAST
# 0.24395946999220577 RF-CV
# 0.23850350740452064 RF-TFIDF
# 0.2182385035074045 RF-GLOVE
# 0.2299298519095869 RF-W2V
# 0.21434138737334374 RF-FAST
# 0.24395946999220577 NB-CV
# 0.24707716289945442 NB-TFIDF
# 0.24240062353858144 NB-GLOVE
# 0.23226812159002339 NB-W2V
# 0.22135619641465315 NB-FAST
# 0.23304754481683554 MLP-CV
# 0.23304754481683554 MLP-TFIDF
# 0.23538581449727203 MLP-GLOVE
# 0.25175370226032734 MLP-W2V
# 0.2587685113016368 MLP-FAST
# 0.24240062353858144 EXTRA-CV
# 0.24473889321901793 EXTRA-TFIDF
# 0.2221356196414653 EXTRA-GLOVE
# 0.2377240841777085 EXTRA-W2V
# 0.2049883086515978 EXTRA-FAST
# 0.22135619641465315 KNN-CV
# 0.2221356196414653 KNN-TFIDF
# ...

# %%
table=pd.read_csv('/content/Data/liar6/pred_val.csv')
label_list=np.array(table['label'])
for column in table.columns:
  pred_list=np.array(table[column])
  print(accuracy_score(label_list,pred_list),column)
# Out:
# 0.0 Unnamed: 0
# 1.0 label
# 0.23286604361370716 SVM-CV
# 0.22118380062305296 SVM-TFIDF
# 0.2601246105919003 SVM-W2V
# 0.2523364485981308 SVM-GLOVE
# 0.2570093457943925 SVM-FAST
# 0.2266355140186916 LR-CV
# 0.22819314641744548 LR-TFIDF
# 0.235202492211838 LR-GLOVE
# 0.22819314641744548 LR-W2V
# 0.2484423676012461 LR-FAST
# 0.2546728971962617 RF-CV
# 0.2515576323987539 RF-TFIDF
# 0.22975077881619937 RF-GLOVE
# 0.21728971962616822 RF-W2V
# 0.235202492211838 RF-FAST
# 0.23286604361370716 NB-CV
# 0.23753894080996885 NB-TFIDF
# 0.2336448598130841 NB-GLOVE
# 0.21339563862928349 NB-W2V
# 0.21806853582554517 NB-FAST
# 0.2235202492211838 MLP-CV
# 0.22585669781931464 MLP-TFIDF
# 0.2398753894080997 MLP-GLOVE
# 0.24376947040498442 MLP-W2V
# 0.2546728971962617 MLP-FAST
# 0.25778816199376947 EXTRA-CV
# 0.2616822429906542 EXTRA-TFIDF
# 0.22819314641744548 EXTRA-GLOVE
# 0.22975077881619937 EXTRA-W2V
# 0.24143302180685358 EXTRA-FAST
# 0.23130841121495327 KNN-CV
# 0.2235202492211838 KNN-TFIDF
# ...
